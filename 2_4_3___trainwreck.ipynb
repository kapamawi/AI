# %% [markdown]
# <a href="https://colab.research.google.com/github/kapamawi/AI/blob/main/2_4_3___trainwreck.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Setup

# %%
# !pip install -qU fsspec seaborn "transformers[agents]"

# %%
from google.colab import userdata
from huggingface_hub import login
secret_value_0 = userdata.get('HF_TOKEN')
login(token = secret_value_0 )

# %%
from transformers.agents import HfApiEngine, ReactCodeAgent
import os

# %%
class CFG:
#  model = "meta-llama/Meta-Llama-3.1-70B-Instruct"
  model = "meta-llama/Meta-Llama-3.1-8B-Instruct"

# %% [markdown]
# # Agent

# %%
llm_engine = HfApiEngine(CFG.model)

# %%
agent = ReactCodeAgent(
    tools=[],
    llm_engine=llm_engine,
    additional_authorized_imports=[
        "numpy",
        "pandas",
        "matplotlib.pyplot",
        "seaborn",
        "sklearn",
    ],
    max_iterations= 50,
)

# %% [markdown]
# # Titanic comp

# %%
# !pwd
# Out:
# /content

# %%
#"" SFSG #

# %%
output = agent.run(
      """You are an expert machine learning engineer.
Please train a ML model on "/content/train.csv" to predict the survival for rows of "/content/test.csv".
Output the results under './output.csv'.
Take care to import functions and modules before using them!
"""
)
# Out:
# ======== New task ========
# You are an expert machine learning engineer.
# Please train a ML model on "/content/train.csv" to predict the survival for rows of "/content/test.csv".
# Output the results under './output.csv'.
# Take care to import functions and modules before using them!
#
# === Agent thoughts:
# Thought: To solve this task, I will first load the training data using pandas, then split it into features and target data. Next, I will preprocess the data by encoding categorical variables and scaling numerical data. Then, I will train a machine learning model, in this case, a random forest classifier, on the preprocessed data. Subsequently, I will load the test data and preprocess it in a similar manner. Finally, I will use the trained model to make predictions on the test data and write the results to an output file.
# >>> Agent is executing the code below:
# import pandas as pd
# from sklearn.ensemble import RandomForestClassifier
# ...
